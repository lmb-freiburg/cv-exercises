# %%
run visualize_pfm.py
# Out:
# ['output_monodepth/scannet/scene0000_00-5575.pfm', 'output_monodepth/scannet/scene0000_00-703.pfm', 'output_monodepth/scannet/scene0062_00-1.pfm', 'output_monodepth/scannet/scene0588_01-1816.pfm']
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /project/cv-ws2425/lmb/cv-exercises-internal/ex08_depth_estimation/solution/visualize_pfm.py in <module>
#     298
#     299 if __name__=="__main__":
# --> 300     main()
#
# /project/cv-ws2425/lmb/cv-exercises-internal/ex08_depth_estimation/solution/visualize_pfm.py in main()
#     277
#     278 def main():
# --> 279     samples = sample_reader()
#     280     print(len(samples))
#     281     for sample in samples:
#
# /project/cv-ws2425/lmb/cv-exercises-internal/ex08_depth_estimation/solution/visualize_pfm.py in sample_reader()
#      70     for f in files:
#      71         s = Sample()
# ---> 72         s.load(f)
# ...
